# %% [markdown]
# # 07 - Business Dashboard
#
# Executive view of the frozen model, operational policy, fraud capture and scenario economics.

# %%
from pathlib import Path
import json, sys
import numpy as np
import pandas as pd
from IPython.display import Image, display

ROOT = Path.cwd().resolve()
if ROOT.name == 'notebooks':
    ROOT = ROOT.parent
sys.path.insert(0, str(ROOT / 'src'))
ART = ROOT / 'artifacts'
FIG = ROOT / 'reports' / 'figures'
pd.set_option('display.max_columns', 100)

# %%
display(Image(filename=str(FIG / '10_executive_dashboard.png')))

# %%
business = json.loads((ART / 'business_case.json').read_text())
pd.Series(business['test_metrics'])
# Out:
# Out[0]:
# policy                             f1_threshold
# transactions                              42557
# alerts                                       35
# alert_rate                             0.000822
# true_fraud_alerts                            35
# false_positive_alerts                         0
# precision                                   1.0
# fraud_count_recall                     0.673077
# fraud_amount_capture                   0.562173
# estimated_prevented_fraud_count            28.0
# gross_prevented_loss                   3194.384
# review_cost_total                         140.0
# friction_cost_total                         0.0
# approve_all_cost                        6948.88
# realized_cost                          3894.496
# net_savings                            3054.384
# savings_per_1000_transactions           71.7716
# savings_per_alert                     87.268114
# review_roi                            21.817029
# ...

# %% [markdown]
# Savings are estimated under explicit scenario assumptions and are shown in currency units. The dashboard does not represent realized results from an identified bank.
