# %% [markdown]
# # 03 - Deep Tabular Challenger
#
# A PyTorch MLP compares weighted binary cross-entropy with focal loss under the same chronological train and validation blocks.

# %%
from pathlib import Path
import json, sys
import numpy as np
import pandas as pd
from IPython.display import Image, display

ROOT = Path.cwd().resolve()
if ROOT.name == 'notebooks':
    ROOT = ROOT.parent
sys.path.insert(0, str(ROOT / 'src'))
ART = ROOT / 'artifacts'
FIG = ROOT / 'reports' / 'figures'
pd.set_option('display.max_columns', 100)

# %%
pd.read_csv(ART / 'deep_validation_comparison.csv')
# Out:
# Out[0]:
#               model  validation_pr_auc  epochs_run
# 0         mlp_focal           0.801050          13
# 1  mlp_weighted_bce           0.752397          10

# %%
json.loads((ART / 'deep_challenger.json').read_text())
# Out:
# Out[0]:
# {'selected_loss': 'focal',
#  'selection_metric': 'validation_pr_auc',
#  'validation_pr_auc': 0.8010497327960754,
#  'epochs_run': 13,
#  'selected_overall': True,
#  'final_test_metrics': {'roc_auc': 0.965481662790803,
#   'pr_auc': 0.79249129416188,
#   'pr_auc_lift': 648.5779231855217,
#   'brier': 0.0003868564262608826,
#   'brier_skill': 0.6830078831379647,
#   'log_loss': 0.002817031336273878,
#   'precision': 0.9487179487179487,
#   'recall': 0.7115384615384616,
#   'f1': 0.8131868131868132,
#   'balanced_accuracy': 0.8557457041253065,
#   'mcc': 0.821433905473039,
#   'threshold': 0.5,
#   'alerts': 39,
#   'prevalence': 0.0012218906407876495,
#   'pr_auc_95pct_interval': [0.6901998674105895,
#    0.7926461175697925,
#    0.892265535653082]}}

# %%
display(Image(filename=str(FIG / '04_deep_training.png')))

# %% [markdown]
# The neural network is a controlled challenger. It is not assumed to outperform gradient-boosted trees on low-dimensional tabular data.
